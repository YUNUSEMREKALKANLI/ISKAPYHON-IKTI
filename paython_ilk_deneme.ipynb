# %%
print ("Merhaba DUNYA") # prnit ekrana çıktı veren kod
# Out:
# Merhaba DUNYA

# %% [markdown]
# paytın proglma dilini prnit komut ekrandna kulanııcya bilgi veren bir koddur
# 08\06\2024 veri yapıları  argo dersin ilk kodudur

# %%
import sys #import python proglma dilinde yazılıma kütüphane eklemeye yarayan kod bloğudur

print (sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive # google colab - drive bağlantısı
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
os.Chdir(' /content/drive/My Drive/veriyapiları_istka')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-abd1643515bd> in <cell line: 2>()
#       1 import os
# ----> 2 os.Chdir(' /content/drive/My Drive/veriyapiları_istka')
#
# AttributeError: module 'os' has no attribute 'Chdir'
